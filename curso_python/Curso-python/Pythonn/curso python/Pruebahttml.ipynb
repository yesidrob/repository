# %%
![logo python](https://www.python.org/static/community_logos/python-logo-master-v3-TM.png)
# Out:
# "[logo" no se reconoce como un comando interno o externo,
# programa o archivo por lotes ejecutable.
